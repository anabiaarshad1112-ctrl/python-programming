# %%
print("anabia")
# Out:
# anabia

# %%
age=19
print(age)
# Out:
# 19

# %%
name = "anabia"
print(name + " is a good coder")
# Out:
# anabia is a good coder

# %%
is_coder = True
print(is_coder)
# Out:
# True

# %%
print (2 + 3)
print (2 - 3)
# Out:
# 2

# %%
print (2 * 3)
print (2 / 3)
print (2 ** 3)
print (2 % 3)
# Out:
# 6
# 0.6666666666666666
# 8
# 2
